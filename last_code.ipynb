# %%
import pandas as pd
import numpy as np
import os
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.layers import LSTM, Dense
from sklearn.preprocessing import StandardScaler
import datetime
from tensorflow.keras import backend as K
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from keras.optimizers import SGD
# Out:
# c:\Anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
def list_subdirectories(directory_path):
    subdirectories =  [subdir for subdir in os.listdir(directory_path) if os.path.isdir(os.path.join(directory_path, subdir))]
    return subdirectories

train_doc_list = list_subdirectories('train')

test_doc_list = list_subdirectories('test')


total_gnss_df = pd.DataFrame({})
total_imu_df = pd.DataFrame({})
total_gt_df = pd.DataFrame({})

def utc_to_unix_millis(utc_millis_array):
    # Unix epoch start time in milliseconds
    unix_epoch_start = np.datetime64('1970-01-01T00:00:00', 'ms').astype('datetime64[ms]').astype(int)
    # Convert UTC time array to Unix time array
    unix_millis_array = np.array(utc_millis_array) - unix_epoch_start
    return unix_millis_array

def unix_to_utc_millis(unix_millis_array):
    # Unix epoch start time in milliseconds
    unix_epoch_start = np.datetime64('1970-01-01T00:00:00', 'ms').astype('datetime64[ms]').astype(int)
    # Convert Unix time array to UTC time array
    utc_millis_array = np.array(unix_millis_array) + unix_epoch_start
    return utc_millis_array

scaler = StandardScaler()

# %% [markdown]
# Models:

# %%
# Model architecture
model_rnn = Sequential()
model_rnn.add(SimpleRNN(units=128, return_sequences=True, input_shape=(20,1 )))  
model_rnn.add(SimpleRNN(units=64, return_sequences=True, activation='tanh'))
model_rnn.add(SimpleRNN(units=32,activation='tanh'))  
model_rnn.add(Dense(2))

# Compile the model
optimizer = SGD(learning_rate=0.001)
model_rnn.compile(loss='mse', optimizer=optimizer)

# %%
# Define the combined CNN-GRU model
def create_cnn_gru_model(input_shape, l2_reg=0.01):
    model = tf.keras.Sequential([
        # CNN layers
        tf.keras.layers.Reshape((-1, 1), input_shape=input_shape),  # Reshape for Conv1D input
        tf.keras.layers.Conv1D(filters=128, kernel_size=3, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(l2_reg)),
        tf.keras.layers.MaxPooling1D(pool_size=2),
        tf.keras.layers.Conv1D(filters=64, kernel_size=3, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(l2_reg)),
        tf.keras.layers.MaxPooling1D(pool_size=2),
        tf.keras.layers.Flatten(),
        
        # GRU layer
        tf.keras.layers.Reshape((-1, 64)),  # Reshape for GRU input
        tf.keras.layers.GRU(48),
        
        # Dense output layer
        tf.keras.layers.Dense(2)  # Output layer for predicting 2 new features
    ])
    return model

# Define the model
input_shape = (None, 21)  # Adjust according to your data dimensions (21 features)
model_cnn_gru = create_cnn_gru_model(input_shape)

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)  # Set the learning rate to 0.001

# Compile the model with the customized optimizer
model_cnn_gru.compile(optimizer=optimizer, loss='mae')


# Function to train the model on a single file with gradient clipping
def train_model_on_file(model, x_train, y_train, clip_norm=1.0):
    model.fit(x_train, y_train, epochs=10, batch_size=16)  # Train the model

# %%
# Create a linear regression model
model = LinearRegression()

# %% [markdown]
# ## TRAIN

# %% [markdown]
# Reading the trainin data and preprocessing:

# %% [markdown]
# !!!!!!!! DO NOT RUN THIS SECTIONS. IT IS ONLY RECREATING THE TRAINING FILES IN THE FORMAT THAT I WILL USE LATER TO TRAIN THE MODELS. THE RECREATED FILES ALREADY INCLUDED AT THE GIVEN .ZIP FILE, SINCE THE TRAIN DATA GIVEN IS CONSUMES TOO MUCH STORAGE I DID NOT INCLUDE THEM FOR YOU TO DOWNLOAD THEM AGAIN. !!!!!!!!!!!!!!

# %%
counter = 0
for main_doc_name in train_doc_list:
    sub_sub_list = list_subdirectories('train'+'/'+main_doc_name)
    
    for doc_name_list in sub_sub_list:
        
        #GNSS Data Part:

        #Reading the present gnss csv file
        df_gnss = pd.read_csv('train'+'/'+main_doc_name+'/'+doc_name_list+'/'+'device_gnss.csv', low_memory=False)

        data_gnss = pd.DataFrame()
        #Taking only the necessary columns
        data_gnss['utcTimeMillis'] =  df_gnss["utcTimeMillis"]
        data_gnss['SvVelocityYEcefMetersPerSecond'] = df_gnss["SvVelocityYEcefMetersPerSecond"]
        data_gnss['SvVelocityZEcefMetersPerSecond'] = df_gnss['SvVelocityZEcefMetersPerSecond']
        data_gnss['SvVelocityXEcefMetersPerSecond'] = df_gnss['SvVelocityXEcefMetersPerSecond']
        data_gnss['RawPseudorangeMeters'] = df_gnss['RawPseudorangeMeters']
        data_gnss['SvClockBiasMeters'] = df_gnss['SvClockBiasMeters']
        data_gnss['IsrbMeters'] = df_gnss['IsrbMeters']
        data_gnss['TroposphericDelayMeters'] = df_gnss['TroposphericDelayMeters']
        data_gnss['IonosphericDelayMeters'] = df_gnss['IonosphericDelayMeters']
        data_gnss['WlsPositionXEcefMeters'] = df_gnss['WlsPositionXEcefMeters']
        data_gnss['WlsPositionYEcefMeters'] = df_gnss['WlsPositionYEcefMeters']
        data_gnss['WlsPositionZEcefMeters'] = df_gnss['WlsPositionZEcefMeters']
               

        #If more than one measurement is taken in the same second, average the measurements taken for the same time period and create one line of data for each second
        ten_digit_gnss = data_gnss.copy()
        ten_digit_gnss['utcTimeMillis'] = data_gnss['utcTimeMillis'].astype(str).str[:10].astype(int)
        gnss_data = ten_digit_gnss.groupby('utcTimeMillis').mean().reset_index()
        gnss_data = gnss_data.fillna(method='ffill')


        #IMU Data Part:
        #Reading the present imu csv file
        df_imu = pd.read_csv('train'+'/'+main_doc_name+'/'+doc_name_list+'/'+'device_imu.csv', low_memory=False)

        # Transforming it to Pandas DataFrame to be able to make moves easily
        data_imu = pd.DataFrame()

        #Taking only the necessary columns
        data_imu['MessageType'] =  df_imu["MessageType"]
        data_imu['utcTimeMillis'] =  df_imu["utcTimeMillis"]
        data_imu['MeasurementX'] =  df_imu["MeasurementX"]
        data_imu['MeasurementY'] = df_imu["MeasurementY"]
        data_imu['MeasurementZ'] = df_imu['MeasurementZ']
        
        #Since the accelerometer, gyro and magnetometer are combined in the same sensor in the IMU, it can be seen that the data received from these sensors 
        #are stored in a mixed manner. To fix this and evaluate each sensor data on its own, three sensor data are transferred to three different dataframes
        accel_imu_data = data_imu.loc[data_imu['MessageType'] == 'UncalAccel']
        mag_imu_data = data_imu.loc[data_imu['MessageType'] == 'UncalMag']
        gyro_imu_data = data_imu.loc[data_imu['MessageType'] == 'UncalGyro']
        
        #For the next step empty DataFrames are created
        ten_digit_accel = accel_imu_data.copy()
        ten_digit_mag = mag_imu_data.copy()
        ten_digit_gyro = gyro_imu_data.copy()

        #Data is currently processed and stored with millisecond precision, removing the last three digits to convert it to seconds precision
        ten_digit_accel['utcTimeMillis'] = accel_imu_data['utcTimeMillis'].astype(str).str[:10].astype(int)
        ten_digit_mag['utcTimeMillis'] = mag_imu_data['utcTimeMillis'].astype(str).str[:10].astype(int)
        ten_digit_gyro['utcTimeMillis'] = gyro_imu_data['utcTimeMillis'].astype(str).str[:10].astype(int)
        
        #If more than one measurement is taken in the same second, average the measurements taken for the same time period and create one line of data for each second
        imu_accel_df = ten_digit_accel.groupby('utcTimeMillis').mean().reset_index()
        imu_mag_df = ten_digit_mag.groupby('utcTimeMillis').mean().reset_index()
        imu_gyro_df = ten_digit_gyro.groupby('utcTimeMillis').mean().reset_index()

        imu_accel_df = imu_accel_df.fillna(method='ffill')
        imu_mag_df = imu_mag_df.fillna(method='ffill')
        imu_gyro_df = imu_gyro_df.fillna(method='ffill')


        #Since measurements for each sensor are recorded with the same column name, column names are customized for each sensor type to avoid confusion when combining data
        imu_accel_df = imu_accel_df.rename(columns={'MeasurementX': 'Accel_MeasurementX'})
        imu_accel_df = imu_accel_df.rename(columns={'MeasurementY': 'Accel_MeasurementY'})
        imu_accel_df = imu_accel_df.rename(columns={'MeasurementZ': 'Accel_MeasurementZ'})
        imu_mag_df = imu_mag_df.rename(columns={'MeasurementX': 'Mag_MeasurementX'})
        imu_mag_df = imu_mag_df.rename(columns={'MeasurementY': 'Mag_MeasurementY'})
        imu_mag_df = imu_mag_df.rename(columns={'MeasurementZ': 'Mag_MeasurementZ'})
        imu_gyro_df = imu_gyro_df.rename(columns={'MeasurementX': 'Gyro_MeasurementX'})
        imu_gyro_df = imu_gyro_df.rename(columns={'MeasurementY': 'Gyro_MeasurementY'})
        imu_gyro_df = imu_gyro_df.rename(columns={'MeasurementZ': 'Gyro_MeasurementZ'})

        #Recombining the processed imu data. Here, the same rows are determined by time, rows with the same time value are combined and the columns of 
        #accel, mag, and gyro measurements are stored separately. 
        total_imu_df = pd.merge(imu_accel_df, imu_mag_df, on='utcTimeMillis', how='inner')
        total_imu_df = pd.merge(total_imu_df, imu_gyro_df, on='utcTimeMillis', how='inner')

        total_imu_df = total_imu_df.fillna(method='ffill')
        
        #Finally, gnss and imu data are paired to take time into account and a single data is created. Thus, the 'X' part of the 
        #data set that will be used later when training the model is created
        x_part = pd.merge(gnss_data, total_imu_df, on='utcTimeMillis', how='inner')
        x_part = x_part.fillna(method='ffill')

        
        #Ground_Truth Data Part:
        df_truth = pd.read_csv('train'+'/'+main_doc_name+'/'+doc_name_list+'/'+'ground_truth.csv')
        data_gt = {'UnixTimeMillis': df_truth["UnixTimeMillis"],
                'LatitudeDegrees': df_truth["LatitudeDegrees"],
                'LongitudeDegrees':df_truth["LongitudeDegrees"],
                'AltitudeMeters':df_truth['AltitudeMeters']
                }
        data_gt = pd.DataFrame(data_gt)
        
        #The time values are arranged according to the data that will be used as 'X' data when training the model. The values UnixTimeMillis column are arranged as to be 10 
        #digit numbers. 
        ten_digit_gt = data_gt.copy()
        ten_digit_gt['UnixTimeMillis'] = unix_to_utc_millis(ten_digit_gt['UnixTimeMillis'] )
        ten_digit_gt['UnixTimeMillis'] = data_gt['UnixTimeMillis'].astype(str).str[:10].astype(int)

        #The column names are set to be the same with the previous data
        ten_digit_gt = ten_digit_gt.rename(columns={'UnixTimeMillis': 'utcTimeMillis'})
        
        #The y part of the training data for training the model
        y_part = ten_digit_gt
                
        #Finally matching the 'x', and the 'y' parts of the data set according to time.
        merged_training_data = pd.merge(x_part, y_part, on='utcTimeMillis', how='inner')
        merged_training_data = merged_training_data.fillna(method='ffill')
                
        
        y_train = merged_training_data[['LatitudeDegrees', 'LongitudeDegrees']]
        x_train = merged_training_data.drop(columns=['LatitudeDegrees', 'LongitudeDegrees', 'AltitudeMeters'])
        x_train_wt = merged_training_data.drop(columns=['utcTimeMillis','LatitudeDegrees', 'LongitudeDegrees', 'AltitudeMeters'])

        
        # Fit the scaler to the data and transform the dataframe
        x_train_normilized = pd.DataFrame(scaler.fit_transform(x_train), columns=x_train.columns)
        x_train_wt_normilized = pd.DataFrame(scaler.fit_transform(x_train_wt), columns=x_train_wt.columns)
        
        #Last Check
        x_train = x_train.fillna(method='ffill')
        x_train_wt = x_train_wt.fillna(method='ffill')
        y_train = y_train.fillna(method='ffill')
                
        #saving the file
        file_path = main_doc_name
        merged_training_data.to_csv(f'train_data2/{file_path}_{counter}.csv', index=False)
        counter = counter + 1
        print('counter:', counter)
# Out:
# counter: 1
# counter: 2
# counter: 3
# counter: 4
# counter: 5
# counter: 6
# counter: 7
# counter: 8
# counter: 9
# counter: 10
# counter: 11
# counter: 12
# counter: 13
# counter: 14
# counter: 15
# counter: 16
# counter: 17
# counter: 18
# counter: 19
# counter: 20
# counter: 21
# counter: 22
# counter: 23
# counter: 24
# counter: 25
# counter: 26
# counter: 27
# counter: 28
# counter: 29
# counter: 30
# counter: 31
# counter: 32
# counter: 33
# counter: 34
# counter: 35
# counter: 36
# counter: 37
# counter: 38
# counter: 39
# counter: 40
# counter: 41
# counter: 42
# counter: 43
# counter: 44
# counter: 45
# counter: 46
# counter: 47
# counter: 48
# counter: 49
# counter: 50
# counter: 51
# counter: 52
# counter: 53
# counter: 54
# counter: 55
# counter: 56
# counter: 57
# counter: 58
# counter: 59
# counter: 60
# counter: 61
# counter: 62
# counter: 63
# counter: 64
# counter: 65
# counter: 66
# counter: 67
# counter: 68
# counter: 69
# counter: 70
# counter: 71
# counter: 72
# counter: 73
# counter: 74
# counter: 75
# counter: 76
# counter: 77
# counter: 78
# counter: 79
# counter: 80
# counter: 81
# counter: 82
# counter: 83
# counter: 84
# counter: 85
# counter: 86
# counter: 87
# counter: 88
# counter: 89
# counter: 90
# counter: 91
# counter: 92
# counter: 93
# counter: 94
# counter: 95
# counter: 96
# counter: 97
# counter: 98
# counter: 99
# counter: 100
# counter: 101
# counter: 102
# counter: 103
# counter: 104
# counter: 105
# counter: 106
# counter: 107
# counter: 108
# counter: 109
# counter: 110
# counter: 111
# counter: 112
# counter: 113
# counter: 114
# counter: 115
# counter: 116
# counter: 117
# counter: 118
# counter: 119
# counter: 120
# counter: 121
# counter: 122
# counter: 123
# counter: 124
# counter: 125
# counter: 126
# counter: 127
# counter: 128
# counter: 129
# counter: 130
# counter: 131
# counter: 132
# counter: 133
# counter: 134
# counter: 135
# counter: 136
# counter: 137
# counter: 138
# counter: 139
# counter: 140
# counter: 141
# counter: 142
# counter: 143
# counter: 144
# counter: 145
# counter: 146
# counter: 147
# counter: 148
# counter: 149
# counter: 150
# counter: 151
# counter: 152
# counter: 153
# counter: 154
# counter: 155
# counter: 156

# %%
# Directory containing the CSV files
folder_path = 'train_data'

# List all files in the directory
file_names = os.listdir(folder_path)

# Filter CSV files
csv_files = [file for file in file_names if file.endswith('.csv')]

# %% [markdown]
# - Train RNN model:

# %%
for doc_name in csv_files:
    #Reading the csv files
    data = pd.read_csv('train_data'+'/'+ doc_name, low_memory=False)
    #print('data', data)
    x_data_to_train_wt = data.copy() 
    y_data_to_train = data.copy()

    x_data_to_train_wt = x_data_to_train_wt.drop(columns=['utcTimeMillis','LatitudeDegrees','LongitudeDegrees','AltitudeMeters'])
    
    #print('x_data_to_train_wt', x_data_to_train_wt)
    y_data_to_train = y_data_to_train.drop(columns=['utcTimeMillis','SvVelocityYEcefMetersPerSecond','SvVelocityZEcefMetersPerSecond','SvVelocityXEcefMetersPerSecond',
                                                    'RawPseudorangeMeters','SvClockBiasMeters','IsrbMeters','TroposphericDelayMeters','IonosphericDelayMeters',
                                                    'WlsPositionXEcefMeters','WlsPositionYEcefMeters','WlsPositionZEcefMeters','Accel_MeasurementX','Accel_MeasurementY',
                                                    'Accel_MeasurementZ','Mag_MeasurementX','Mag_MeasurementY','Mag_MeasurementZ','Gyro_MeasurementX','Gyro_MeasurementY',
                                                    'Gyro_MeasurementZ','AltitudeMeters'])
    
    #print('y_data_to_train',y_data_to_train)
    #Train the RNN model
    los=model_rnn.train_on_batch(x_data_to_train_wt, y_data_to_train)
    print(los)
# Out:
# 8215.587890625
# 7570.44384765625
# 7249.79443359375
# 6661.26220703125
# 7105.26904296875
# 7570.7021484375
# 7380.84033203125
# 8246.0634765625
# 8649.3798828125
# 7891.85986328125
# 7551.3115234375
# 6294.05615234375
# 5801.63330078125
# 10709.4619140625
# 9314.25
# 6061.09814453125
# 6624.478515625
# 6762.5927734375
# 9789.892578125
# 5755.07421875
# 6430.46630859375
# 9921.712890625
# 5410.4033203125
# 6254.15576171875
# 10018.3037109375
# 5261.07763671875
# 9490.9384765625
# 4750.3583984375
# 8381.099609375
# 7757.2431640625
# 8248.1943359375
# 7683.681640625
# 8196.466796875
# 7645.25732421875
# 6792.833984375
# 6171.34423828125
# 9839.8681640625
# 6185.35888671875
# 9565.27734375
# 7589.3134765625
# 8324.5771484375
# 6716.98828125
# 6494.54443359375
# 6708.26611328125
# 6475.62158203125
# 5783.1640625
# 9491.1728515625
# 5745.80078125
# 9459.87890625
# 9970.37109375
# 5944.66796875
# 5329.4306640625
# 5293.16064453125
# 10930.48828125
# 4741.927734375
# 4384.11865234375
# 4098.64794921875
# 11849.802734375
# 4259.634765625
# 3609.265869140625
# 11258.302734375
# 3714.97802734375
# 3414.330810546875
# 3197.027587890625
# 11908.7158203125
# 3395.021728515625
# 3151.228271484375
# 11880.25390625
# 3310.896240234375
# 3099.0703125
# 2896.968505859375
# 12081.3095703125
# 3259.177490234375
# 3033.703857421875
# 11800.0791015625
# 3458.373779296875
# 3570.436767578125
# 3338.550537109375
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
#       1 for doc_name in csv_files:
#       2     #Reading the csv files
# ----> 3     data = pd.read_csv('train_data'+'/'+ doc_name, low_memory=False)
#       4     #print('data', data)
#       5     x_data_to_train_wt = data.copy()
#
# File c:\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File c:\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File c:\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File c:\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1235, in TextFileReader._make_engine(self, f, engine)
#    1232     raise ValueError(msg)
#    1234 try:
# -> 1235     return mapping[engine](f, **self.options)
#    1236 except Exception:
#    1237     if self.handles is not None:
#
# File c:\Anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:75, in CParserWrapper.__init__(self, src, **kwds)
#      72     kwds.pop(key, None)
#      74 kwds["dtype"] = ensure_dtype_objs(kwds.get("dtype", None))
# ---> 75 self._reader = parsers.TextReader(src, **kwds)
#      77 self.unnamed_cols = self._reader.unnamed_cols
#      79 # error: Cannot determine type of 'names'
#
# KeyboardInterrupt:

# %% [markdown]
# - Train LR model:

# %%
for doc_name in csv_files:
    #Reading the csv files
    data = pd.read_csv('train_data'+'/'+ doc_name, low_memory=False)
    
    x_data_to_train = data.copy() 
    y_data_to_train = data.copy()

    x_data_to_train_wt = x_data_to_train.drop(columns=['utcTimeMillis','LatitudeDegrees','LongitudeDegrees','AltitudeMeters'], inplace=True)
    y_data_to_train = y_data_to_train.drop(columns=['utcTimeMillis','SvVelocityYEcefMetersPerSecond','SvVelocityZEcefMetersPerSecond','SvVelocityXEcefMetersPerSecond',
                                                    'RawPseudorangeMeters','SvClockBiasMeters','IsrbMeters','TroposphericDelayMeters','IonosphericDelayMeters',
                                                    'WlsPositionXEcefMeters','WlsPositionYEcefMeters','WlsPositionZEcefMeters','Accel_MeasurementX','Accel_MeasurementY',
                                                    'Accel_MeasurementZ','Mag_MeasurementX','Mag_MeasurementY','Mag_MeasurementZ','Gyro_MeasurementX','Gyro_MeasurementY',
                                                    'Gyro_MeasurementZ','AltitudeMeters'], inplace=True)
    #Train the LR model
    model.fit(x_train_wt, y_train)

# %% [markdown]
# - Train CNN-GRU model:

# %%
for doc_name in csv_files:
    #Reading the csv files
    data = pd.read_csv('train_data'+'/'+ doc_name, low_memory=False)
    
    x_data_to_train = data.copy() 
    y_data_to_train = data.copy()

    x_data_to_train_wt = x_data_to_train.drop(columns=['utcTimeMillis','LatitudeDegrees','LongitudeDegrees','AltitudeMeters'], inplace=True)
    y_data_to_train = y_data_to_train.drop(columns=['utcTimeMillis','SvVelocityYEcefMetersPerSecond','SvVelocityZEcefMetersPerSecond','SvVelocityXEcefMetersPerSecond',
                                                    'RawPseudorangeMeters','SvClockBiasMeters','IsrbMeters','TroposphericDelayMeters','IonosphericDelayMeters',
                                                    'WlsPositionXEcefMeters','WlsPositionYEcefMeters','WlsPositionZEcefMeters','Accel_MeasurementX','Accel_MeasurementY',
                                                    'Accel_MeasurementZ','Mag_MeasurementX','Mag_MeasurementY','Mag_MeasurementZ','Gyro_MeasurementX','Gyro_MeasurementY',
                                                    'Gyro_MeasurementZ','AltitudeMeters'], inplace=True)
    # Train the CNN-GRU MODEL:
    train_model_on_file(model_cnn_gru, x_train_wt, y_train)
# Out:
# Epoch 1/10
# 130/130 [==============================] - 2s 3ms/step - loss: 79.8702
# Epoch 2/10
# 130/130 [==============================] - 0s 3ms/step - loss: 76.4384
# Epoch 3/10
# 130/130 [==============================] - 0s 4ms/step - loss: 71.4972
# Epoch 4/10
# 130/130 [==============================] - 0s 4ms/step - loss: 66.6111
# Epoch 5/10
# 130/130 [==============================] - 1s 4ms/step - loss: 63.3117
# Epoch 6/10
# 130/130 [==============================] - 0s 4ms/step - loss: 66.0419
# Epoch 7/10
# 130/130 [==============================] - 0s 4ms/step - loss: 61.2039
# Epoch 8/10
# 130/130 [==============================] - 0s 4ms/step - loss: 56.4850
# Epoch 9/10
# 130/130 [==============================] - 0s 3ms/step - loss: 51.8159
# Epoch 10/10
# 130/130 [==============================] - 0s 3ms/step - loss: 47.1755
# Epoch 1/10
# 130/130 [==============================] - 0s 4ms/step - loss: 42.9694
# Epoch 2/10
# 130/130 [==============================] - 0s 4ms/step - loss: 40.4753
# Epoch 3/10
# 130/130 [==============================] - 0s 4ms/step - loss: 38.1742
# Epoch 4/10
# 130/130 [==============================] - 0s 4ms/step - loss: 35.8766
# Epoch 5/10
# 130/130 [==============================] - 1s 4ms/step - loss: 33.5824
# Epoch 6/10
# 130/130 [==============================] - 1s 4ms/step - loss: 31.2914
# Epoch 7/10
# 130/130 [==============================] - 0s 4ms/step - loss: 29.0017
# Epoch 8/10
# 130/130 [==============================] - 1s 4ms/step - loss: 26.7144
# Epoch 9/10
# 130/130 [==============================] - 1s 5ms/step - loss: 24.4288
# Epoch 10/10
# 130/130 [==============================] - 1s 5ms/step - loss: 22.1442
# Epoch 1/10
# 130/130 [==============================] - 1s 5ms/step - loss: 19.8610
# Epoch 2/10
# 130/130 [==============================] - 0s 4ms/step - loss: 31.9881
# Epoch 3/10
# 130/130 [==============================] - 0s 4ms/step - loss: 33.3981
# Epoch 4/10
# 130/130 [==============================] - 0s 3ms/step - loss: 29.3451
# Epoch 5/10
# 130/130 [==============================] - 0s 3ms/step - loss: 27.3442
# Epoch 6/10
# 130/130 [==============================] - 0s 4ms/step - loss: 25.4463
# Epoch 7/10
# 130/130 [==============================] - 0s 4ms/step - loss: 23.5664
# Epoch 8/10
# 130/130 [==============================] - 0s 4ms/step - loss: 21.6982
# Epoch 9/10
# 130/130 [==============================] - 0s 4ms/step - loss: 26.7264
# Epoch 10/10
# 130/130 [==============================] - 0s 4ms/step - loss: 23.9226
# Epoch 1/10
# 130/130 [==============================] - 0s 4ms/step - loss: 21.8916
# Epoch 2/10
# 130/130 [==============================] - 1s 4ms/step - loss: 19.8797
# Epoch 3/10
# 130/130 [==============================] - 0s 3ms/step - loss: 17.8780
# Epoch 4/10
# 130/130 [==============================] - 0s 4ms/step - loss: 15.8843
# Epoch 5/10
# 130/130 [==============================] - 0s 3ms/step - loss: 13.8969
# Epoch 6/10
# 130/130 [==============================] - 1s 4ms/step - loss: 11.9152
# Epoch 7/10
# 130/130 [==============================] - 0s 4ms/step - loss: 9.9381
# Epoch 8/10
# 130/130 [==============================] - 0s 4ms/step - loss: 7.9644
# Epoch 9/10
# 130/130 [==============================] - 0s 4ms/step - loss: 5.9936
# Epoch 10/10
# 130/130 [==============================] - 0s 4ms/step - loss: 4.6115
# Epoch 1/10
# 130/130 [==============================] - 0s 4ms/step - loss: 2.0799
# Epoch 2/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.3871
# Epoch 3/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1651
# Epoch 4/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1640
# Epoch 5/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1633
# Epoch 6/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1620
# Epoch 7/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1608
# Epoch 8/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1599
# Epoch 9/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1586
# Epoch 10/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1574
# Epoch 1/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1568
# Epoch 2/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1549
# Epoch 3/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1537
# Epoch 4/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1523
# Epoch 5/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1510
# Epoch 6/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1497
# Epoch 7/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1489
# Epoch 8/10
# 130/130 [==============================] - 0s 3ms/step - loss: 12.5980
# Epoch 9/10
# 130/130 [==============================] - 0s 3ms/step - loss: 23.2938
# Epoch 10/10
# 130/130 [==============================] - 0s 4ms/step - loss: 17.3300
# Epoch 1/10
# 130/130 [==============================] - 0s 4ms/step - loss: 14.1972
# Epoch 2/10
# 130/130 [==============================] - 0s 3ms/step - loss: 11.7571
# Epoch 3/10
# 130/130 [==============================] - 0s 3ms/step - loss: 9.4448
# Epoch 4/10
# 130/130 [==============================] - 0s 3ms/step - loss: 7.2296
# Epoch 5/10
# 130/130 [==============================] - 1s 4ms/step - loss: 5.0903
# Epoch 6/10
# 130/130 [==============================] - 0s 3ms/step - loss: 3.0116
# Epoch 7/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.9942
# Epoch 8/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1807
# Epoch 9/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1784
# Epoch 10/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1766
# Epoch 1/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1746
# Epoch 2/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1732
# Epoch 3/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1718
# Epoch 4/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1696
# Epoch 5/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1681
# Epoch 6/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1664
# Epoch 7/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1645
# Epoch 8/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1624
# Epoch 9/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1606
# Epoch 10/10
# 130/130 [==============================] - 0s 3ms/step - loss: 1.1708
# Epoch 1/10
# 130/130 [==============================] - 0s 3ms/step - loss: 1.7331
# Epoch 2/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1603
# Epoch 3/10
# 130/130 [==============================] - 0s 4ms/step - loss: 12.8014
# Epoch 4/10
# 130/130 [==============================] - 0s 3ms/step - loss: 9.7746
# Epoch 5/10
# 130/130 [==============================] - 0s 3ms/step - loss: 6.5701
# Epoch 6/10
# 130/130 [==============================] - 0s 3ms/step - loss: 3.7831
# Epoch 7/10
# 130/130 [==============================] - 1s 4ms/step - loss: 1.1892
# Epoch 8/10
# 130/130 [==============================] - 0s 3ms/step - loss: 40.2713
# Epoch 9/10
# 130/130 [==============================] - 0s 3ms/step - loss: 40.6851
# Epoch 10/10
# 130/130 [==============================] - 0s 3ms/step - loss: 34.8300
# Epoch 1/10
# 130/130 [==============================] - 0s 3ms/step - loss: 29.8882
# Epoch 2/10
# 130/130 [==============================] - 1s 4ms/step - loss: 27.2856
# Epoch 3/10
# 130/130 [==============================] - 0s 4ms/step - loss: 24.9918
# Epoch 4/10
# 130/130 [==============================] - 0s 4ms/step - loss: 22.7407
# Epoch 5/10
# 130/130 [==============================] - 0s 3ms/step - loss: 20.5242
# Epoch 6/10
# 130/130 [==============================] - 0s 4ms/step - loss: 18.3364
# Epoch 7/10
# 130/130 [==============================] - 0s 3ms/step - loss: 16.1734
# Epoch 8/10
# 130/130 [==============================] - 0s 4ms/step - loss: 14.0296
# Epoch 9/10
# 130/130 [==============================] - 0s 3ms/step - loss: 11.9031
# Epoch 10/10
# 130/130 [==============================] - 0s 3ms/step - loss: 9.7914
# Epoch 1/10
# 130/130 [==============================] - 0s 3ms/step - loss: 7.6921
# Epoch 2/10
# 130/130 [==============================] - 0s 3ms/step - loss: 5.6036
# Epoch 3/10
# 130/130 [==============================] - 1s 4ms/step - loss: 3.5245
# Epoch 4/10
# 130/130 [==============================] - 0s 3ms/step - loss: 1.4536
# Epoch 5/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.2268
# Epoch 6/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2119
# Epoch 7/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2104
# Epoch 8/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.2090
# Epoch 9/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.8347
# Epoch 10/10
# 130/130 [==============================] - 0s 4ms/step - loss: 1.9716
# Epoch 1/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.7334
# Epoch 2/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2046
# Epoch 3/10
# 130/130 [==============================] - 0s 4ms/step - loss: 3.7987
# Epoch 4/10
# 130/130 [==============================] - 0s 4ms/step - loss: 2.7735
# Epoch 5/10
# 130/130 [==============================] - 0s 3ms/step - loss: 1.1230
# Epoch 6/10
# 130/130 [==============================] - 0s 3ms/step - loss: 1.4373
# Epoch 7/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.2387
# Epoch 8/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.2335
# Epoch 9/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2329
# Epoch 10/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2316
# Epoch 1/10
# 130/130 [==============================] - 0s 3ms/step - loss: 5.4075
# Epoch 2/10
# 130/130 [==============================] - 0s 3ms/step - loss: 13.2050
# Epoch 3/10
# 130/130 [==============================] - 1s 4ms/step - loss: 8.6906
# Epoch 4/10
# 130/130 [==============================] - 0s 3ms/step - loss: 6.3697
# Epoch 5/10
# 130/130 [==============================] - 0s 3ms/step - loss: 4.2360
# Epoch 6/10
# 130/130 [==============================] - 0s 3ms/step - loss: 2.1755
# Epoch 7/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.4603
# Epoch 8/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.2445
# Epoch 9/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.2431
# Epoch 10/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2424
# Epoch 1/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.2417
# Epoch 2/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2412
# Epoch 3/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.2400
# Epoch 4/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2390
# Epoch 5/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2383
# Epoch 6/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.2373
# Epoch 7/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2364
# Epoch 8/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.2356
# Epoch 9/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2345
# Epoch 10/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.2333
# Epoch 1/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2325
# Epoch 2/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2315
# Epoch 3/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.2309
# Epoch 4/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.2291
# Epoch 5/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.2281
# Epoch 6/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2271
# Epoch 7/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2267
# Epoch 8/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.2252
# Epoch 9/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.2236
# Epoch 10/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2222
# Epoch 1/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2209
# Epoch 2/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2198
# Epoch 3/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.2186
# Epoch 4/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2173
# Epoch 5/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.2159
# Epoch 6/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.2143
# Epoch 7/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.2135
# Epoch 8/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.2111
# Epoch 9/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2096
# Epoch 10/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2079
# Epoch 1/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2067
# Epoch 2/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.2047
# Epoch 3/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2028
# Epoch 4/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2013
# Epoch 5/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1997
# Epoch 6/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1981
# Epoch 7/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1959
# Epoch 8/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1937
# Epoch 9/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1923
# Epoch 10/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1904
# Epoch 1/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1880
# Epoch 2/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1860
# Epoch 3/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1842
# Epoch 4/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1822
# Epoch 5/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1802
# Epoch 6/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1779
# Epoch 7/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1753
# Epoch 8/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1736
# Epoch 9/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1711
# Epoch 10/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1691
# Epoch 1/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1666
# Epoch 2/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1639
# Epoch 3/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1622
# Epoch 4/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1596
# Epoch 5/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1569
# Epoch 6/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1544
# Epoch 7/10
# 130/130 [==============================] - 0s 3ms/step - loss: 8.4190
# Epoch 8/10
# 130/130 [==============================] - 0s 3ms/step - loss: 3.1811
# Epoch 9/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1706
# Epoch 10/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1459
# Epoch 1/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1428
# Epoch 2/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1398
# Epoch 3/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1368
# Epoch 4/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1341
# Epoch 5/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1313
# Epoch 6/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1282
# Epoch 7/10
# 130/130 [==============================] - 0s 3ms/step - loss: 4.4005
# Epoch 8/10
# 130/130 [==============================] - 0s 3ms/step - loss: 2.1866
# Epoch 9/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1500
# Epoch 10/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1419
# Epoch 1/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1402
# Epoch 2/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1384
# Epoch 3/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1370
# Epoch 4/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1365
# Epoch 5/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1353
# Epoch 6/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1336
# Epoch 7/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1321
# Epoch 8/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1310
# Epoch 9/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1302
# Epoch 10/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1292
# Epoch 1/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1277
# Epoch 2/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1272
# Epoch 3/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1261
# Epoch 4/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1246
# Epoch 5/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1242
# Epoch 6/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1232
# Epoch 7/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1228
# Epoch 8/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1219
# Epoch 9/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1213
# Epoch 10/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1206
# Epoch 1/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1206
# Epoch 2/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1192
# Epoch 3/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1194
# Epoch 4/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1181
# Epoch 5/10
# 130/130 [==============================] - 0s 3ms/step - loss: 5.1006
# Epoch 6/10
# 130/130 [==============================] - 1s 4ms/step - loss: 14.8575
# Epoch 7/10
# 130/130 [==============================] - 0s 3ms/step - loss: 8.5328
# Epoch 8/10
# 130/130 [==============================] - 0s 3ms/step - loss: 5.5130
# Epoch 9/10
# 130/130 [==============================] - 0s 3ms/step - loss: 2.8145
# Epoch 10/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.5570
# Epoch 1/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1939
# Epoch 2/10
# 130/130 [==============================] - 0s 3ms/step - loss: 1.7416
# Epoch 3/10
# 130/130 [==============================] - 0s 3ms/step - loss: 1.6832
# Epoch 4/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.2307
# Epoch 5/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.2229
# Epoch 6/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2221
# Epoch 7/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.2217
# Epoch 8/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2219
# Epoch 9/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.2211
# Epoch 10/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2207
# Epoch 1/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2196
# Epoch 2/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2192
# Epoch 3/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.2189
# Epoch 4/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.2188
# Epoch 5/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2177
# Epoch 6/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2172
# Epoch 7/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.2169
# Epoch 8/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.2162
# Epoch 9/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2156
# Epoch 10/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2155
# Epoch 1/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.2145
# Epoch 2/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.2137
# Epoch 3/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2129
# Epoch 4/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2128
# Epoch 5/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.2124
# Epoch 6/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2116
# Epoch 7/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.2105
# Epoch 8/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2092
# Epoch 9/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2087
# Epoch 10/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.2080
# Epoch 1/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.2069
# Epoch 2/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.2068
# Epoch 3/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2055
# Epoch 4/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.2042
# Epoch 5/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2038
# Epoch 6/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.2033
# Epoch 7/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2013
# Epoch 8/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.2001
# Epoch 9/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1997
# Epoch 10/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1989
# Epoch 1/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1974
# Epoch 2/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1963
# Epoch 3/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1951
# Epoch 4/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1934
# Epoch 5/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1925
# Epoch 6/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1914
# Epoch 7/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1904
# Epoch 8/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1886
# Epoch 9/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1871
# Epoch 10/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1857
# Epoch 1/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1841
# Epoch 2/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1828
# Epoch 3/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1806
# Epoch 4/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1791
# Epoch 5/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1774
# Epoch 6/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1756
# Epoch 7/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1733
# Epoch 8/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1722
# Epoch 9/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1696
# Epoch 10/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1681
# Epoch 1/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1657
# Epoch 2/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1641
# Epoch 3/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1616
# Epoch 4/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1594
# Epoch 5/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1569
# Epoch 6/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1546
# Epoch 7/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1526
# Epoch 8/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1503
# Epoch 9/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1473
# Epoch 10/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1449
# Epoch 1/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1431
# Epoch 2/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1397
# Epoch 3/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1371
# Epoch 4/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1343
# Epoch 5/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1314
# Epoch 6/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1291
# Epoch 7/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1256
# Epoch 8/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1227
# Epoch 9/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1199
# Epoch 10/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1175
# Epoch 1/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1146
# Epoch 2/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1112
# Epoch 3/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1084
# Epoch 4/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1053
# Epoch 5/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1024
# Epoch 6/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.0994
# Epoch 7/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0973
# Epoch 8/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0945
# Epoch 9/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.0909
# Epoch 10/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0888
# Epoch 1/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.0852
# Epoch 2/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0820
# Epoch 3/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.0793
# Epoch 4/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0767
# Epoch 5/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0744
# Epoch 6/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.0714
# Epoch 7/10
# 130/130 [==============================] - 0s 3ms/step - loss: 18.2732
# Epoch 8/10
# 130/130 [==============================] - 0s 4ms/step - loss: 12.2031
# Epoch 9/10
# 130/130 [==============================] - 1s 4ms/step - loss: 8.3655
# Epoch 10/10
# 130/130 [==============================] - 0s 3ms/step - loss: 5.8420
# Epoch 1/10
# 130/130 [==============================] - 0s 4ms/step - loss: 13.5883
# Epoch 2/10
# 130/130 [==============================] - 0s 4ms/step - loss: 45.2599
# Epoch 3/10
# 130/130 [==============================] - 0s 3ms/step - loss: 40.6585
# Epoch 4/10
# 130/130 [==============================] - 0s 3ms/step - loss: 36.4425
# Epoch 5/10
# 130/130 [==============================] - 0s 3ms/step - loss: 32.4780
# Epoch 6/10
# 130/130 [==============================] - 1s 4ms/step - loss: 28.7452
# Epoch 7/10
# 130/130 [==============================] - 0s 4ms/step - loss: 26.4329
# Epoch 8/10
# 130/130 [==============================] - 0s 3ms/step - loss: 24.7415
# Epoch 9/10
# 130/130 [==============================] - 0s 3ms/step - loss: 23.0787
# Epoch 10/10
# 130/130 [==============================] - 0s 4ms/step - loss: 21.4396
# Epoch 1/10
# 130/130 [==============================] - 0s 4ms/step - loss: 19.8205
# Epoch 2/10
# 130/130 [==============================] - 0s 3ms/step - loss: 18.2184
# Epoch 3/10
# 130/130 [==============================] - 0s 4ms/step - loss: 16.6304
# Epoch 4/10
# 130/130 [==============================] - 0s 4ms/step - loss: 15.0547
# Epoch 5/10
# 130/130 [==============================] - 0s 4ms/step - loss: 13.4895
# Epoch 6/10
# 130/130 [==============================] - 0s 3ms/step - loss: 11.9334
# Epoch 7/10
# 130/130 [==============================] - 0s 4ms/step - loss: 10.3851
# Epoch 8/10
# 130/130 [==============================] - 0s 4ms/step - loss: 8.8435
# Epoch 9/10
# 130/130 [==============================] - 0s 3ms/step - loss: 7.3079
# Epoch 10/10
# 130/130 [==============================] - 1s 4ms/step - loss: 5.7771
# Epoch 1/10
# 130/130 [==============================] - 0s 3ms/step - loss: 4.2508
# Epoch 2/10
# 130/130 [==============================] - 0s 4ms/step - loss: 2.7285
# Epoch 3/10
# 130/130 [==============================] - 0s 3ms/step - loss: 1.2094
# Epoch 4/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1809
# Epoch 5/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1483
# Epoch 6/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1474
# Epoch 7/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1470
# Epoch 8/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1458
# Epoch 9/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1452
# Epoch 10/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1447
# Epoch 1/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1445
# Epoch 2/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1439
# Epoch 3/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1425
# Epoch 4/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1421
# Epoch 5/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1409
# Epoch 6/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1403
# Epoch 7/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1393
# Epoch 8/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1389
# Epoch 9/10
# 130/130 [==============================] - 0s 3ms/step - loss: 4.9824
# Epoch 10/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.9776
# Epoch 1/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1379
# Epoch 2/10
# 130/130 [==============================] - 0s 3ms/step - loss: 1.5164
# Epoch 3/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2754
# Epoch 4/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1358
# Epoch 5/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1342
# Epoch 6/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1329
# Epoch 7/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1317
# Epoch 8/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1305
# Epoch 9/10
# 130/130 [==============================] - 1s 4ms/step - loss: 5.3904
# Epoch 10/10
# 130/130 [==============================] - 0s 4ms/step - loss: 2.8342
# Epoch 1/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5989
# Epoch 2/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1261
# Epoch 3/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1246
# Epoch 4/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1234
# Epoch 5/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1221
# Epoch 6/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1204
# Epoch 7/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1197
# Epoch 8/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1183
# Epoch 9/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1169
# Epoch 10/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1156
# Epoch 1/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1143
# Epoch 2/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1131
# Epoch 3/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1118
# Epoch 4/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1103
# Epoch 5/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1096
# Epoch 6/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1076
# Epoch 7/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1059
# Epoch 8/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1046
# Epoch 9/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1029
# Epoch 10/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1015
# Epoch 1/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1003
# Epoch 2/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.0985
# Epoch 3/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.0970
# Epoch 4/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.0955
# Epoch 5/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0940
# Epoch 6/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0920
# Epoch 7/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.0900
# Epoch 8/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.0886
# Epoch 9/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0870
# Epoch 10/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.0854
# Epoch 1/10
# 130/130 [==============================] - 0s 3ms/step - loss: 1.9798
# Epoch 2/10
# 130/130 [==============================] - 1s 4ms/step - loss: 2.5364
# Epoch 3/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2059
# Epoch 4/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.0806
# Epoch 5/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0787
# Epoch 6/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0770
# Epoch 7/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.0742
# Epoch 8/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.0726
# Epoch 9/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.0705
# Epoch 10/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0690
# Epoch 1/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.0674
# Epoch 2/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0656
# Epoch 3/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.0645
# Epoch 4/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0624
# Epoch 5/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.0606
# Epoch 6/10
# 130/130 [==============================] - 1s 4ms/step - loss: 1.1926
# Epoch 7/10
# 130/130 [==============================] - 0s 4ms/step - loss: 4.7470
# Epoch 8/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0855
# Epoch 9/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.0760
# Epoch 10/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0748
# Epoch 1/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.0739
# Epoch 2/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.0725
# Epoch 3/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.0719
# Epoch 4/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0704
# Epoch 5/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0697
# Epoch 6/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0688
# Epoch 7/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.0678
# Epoch 8/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.0670
# Epoch 9/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0661
# Epoch 10/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0650
# Epoch 1/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0641
# Epoch 2/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0634
# Epoch 3/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.0621
# Epoch 4/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.0613
# Epoch 5/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.0602
# Epoch 6/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.0660
# Epoch 7/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.6312
# Epoch 8/10
# 130/130 [==============================] - 1s 4ms/step - loss: 3.4343
# Epoch 9/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1854
# Epoch 10/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.0733
# Epoch 1/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1473
# Epoch 2/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0821
# Epoch 3/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0643
# Epoch 4/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.0620
# Epoch 5/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0601
# Epoch 6/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0586
# Epoch 7/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0565
# Epoch 8/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.5777
# Epoch 9/10
# 130/130 [==============================] - 0s 3ms/step - loss: 11.3599
# Epoch 10/10
# 130/130 [==============================] - 0s 3ms/step - loss: 5.6783
# Epoch 1/10
# 130/130 [==============================] - 1s 4ms/step - loss: 2.4216
# Epoch 2/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1837
# Epoch 3/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.0574
# Epoch 4/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.0547
# Epoch 5/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.6232
# Epoch 6/10
# 130/130 [==============================] - 0s 4ms/step - loss: 13.1561
# Epoch 7/10
# 130/130 [==============================] - 0s 3ms/step - loss: 13.7799
# Epoch 8/10
# 130/130 [==============================] - 0s 4ms/step - loss: 10.1729
# Epoch 9/10
# 130/130 [==============================] - 0s 3ms/step - loss: 7.3655
# Epoch 10/10
# 130/130 [==============================] - 0s 4ms/step - loss: 4.7182
# Epoch 1/10
# 130/130 [==============================] - 0s 3ms/step - loss: 2.1862
# Epoch 2/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.2517
# Epoch 3/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.0990
# Epoch 4/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0984
# Epoch 5/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.0980
# Epoch 6/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.0976
# Epoch 7/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.0965
# Epoch 8/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.0968
# Epoch 9/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.0959
# Epoch 10/10
# 130/130 [==============================] - 0s 3ms/step - loss: 1.7888
# Epoch 1/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1253
# Epoch 2/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1122
# Epoch 3/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1122
# Epoch 4/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1113
# Epoch 5/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1118
# Epoch 6/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1114
# Epoch 7/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1113
# Epoch 8/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1106
# Epoch 9/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1108
# Epoch 10/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1101
# Epoch 1/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1098
# Epoch 2/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1093
# Epoch 3/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1092
# Epoch 4/10
# 130/130 [==============================] - 0s 3ms/step - loss: 2.6396
# Epoch 5/10
# 130/130 [==============================] - 0s 3ms/step - loss: 14.8871
# Epoch 6/10
# 130/130 [==============================] - 1s 4ms/step - loss: 10.6845
# Epoch 7/10
# 130/130 [==============================] - 0s 3ms/step - loss: 7.1309
# Epoch 8/10
# 130/130 [==============================] - 0s 3ms/step - loss: 3.8849
# Epoch 9/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.9461
# Epoch 10/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1200
# Epoch 1/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1180
# Epoch 2/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1172
# Epoch 3/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1169
# Epoch 4/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1163
# Epoch 5/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1156
# Epoch 6/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1156
# Epoch 7/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1146
# Epoch 8/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1171
# Epoch 9/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1135
# Epoch 10/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1124
# Epoch 1/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1130
# Epoch 2/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1109
# Epoch 3/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1101
# Epoch 4/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1099
# Epoch 5/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1088
# Epoch 6/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1077
# Epoch 7/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1073
# Epoch 8/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1066
# Epoch 9/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1055
# Epoch 10/10
# 130/130 [==============================] - 0s 3ms/step - loss: 6.1408
# Epoch 1/10
# 130/130 [==============================] - 0s 3ms/step - loss: 24.3916
# Epoch 2/10
# 130/130 [==============================] - 1s 4ms/step - loss: 16.5591
# Epoch 3/10
# 130/130 [==============================] - 0s 4ms/step - loss: 12.9898
# Epoch 4/10
# 130/130 [==============================] - 0s 3ms/step - loss: 9.9598
# Epoch 5/10
# 130/130 [==============================] - 0s 4ms/step - loss: 7.1192
# Epoch 6/10
# 130/130 [==============================] - 0s 4ms/step - loss: 4.4182
# Epoch 7/10
# 130/130 [==============================] - 0s 4ms/step - loss: 1.8241
# Epoch 8/10
# 130/130 [==============================] - 0s 3ms/step - loss: 2.3758
# Epoch 9/10
# 130/130 [==============================] - 0s 4ms/step - loss: 3.6109
# Epoch 10/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.8755
# Epoch 1/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1386
# Epoch 2/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1381
# Epoch 3/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1369
# Epoch 4/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1364
# Epoch 5/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1357
# Epoch 6/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1340
# Epoch 7/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1332
# Epoch 8/10
# 130/130 [==============================] - 0s 4ms/step - loss: 2.9457
# Epoch 9/10
# 130/130 [==============================] - 1s 4ms/step - loss: 6.6117
# Epoch 10/10
# 130/130 [==============================] - 0s 4ms/step - loss: 2.0511
# Epoch 1/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1669
# Epoch 2/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1286
# Epoch 3/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1275
# Epoch 4/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1267
# Epoch 5/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1254
# Epoch 6/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1246
# Epoch 7/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1242
# Epoch 8/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1390
# Epoch 9/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1219
# Epoch 10/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1206
# Epoch 1/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1199
# Epoch 2/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1188
# Epoch 3/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1174
# Epoch 4/10
# 130/130 [==============================] - 1s 5ms/step - loss: 0.1165
# Epoch 5/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1157
# Epoch 6/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1146
# Epoch 7/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1136
# Epoch 8/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1121
# Epoch 9/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1110
# Epoch 10/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1101
# Epoch 1/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1099
# Epoch 2/10
# 130/130 [==============================] - 1s 5ms/step - loss: 0.1087
# Epoch 3/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1071
# Epoch 4/10
# 130/130 [==============================] - 1s 5ms/step - loss: 0.1064
# Epoch 5/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1051
# Epoch 6/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1042
# Epoch 7/10
# 130/130 [==============================] - 1s 5ms/step - loss: 0.1025
# Epoch 8/10
# 130/130 [==============================] - 1s 5ms/step - loss: 0.1020
# Epoch 9/10
# 130/130 [==============================] - 1s 5ms/step - loss: 0.1012
# Epoch 10/10
# 130/130 [==============================] - 1s 5ms/step - loss: 0.0997
# Epoch 1/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.0981
# Epoch 2/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0974
# Epoch 3/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0959
# Epoch 4/10
# 130/130 [==============================] - 1s 4ms/step - loss: 3.0939
# Epoch 5/10
# 130/130 [==============================] - 1s 5ms/step - loss: 1.9952
# Epoch 6/10
# 130/130 [==============================] - 1s 5ms/step - loss: 0.0998
# Epoch 7/10
# 130/130 [==============================] - 1s 6ms/step - loss: 0.0904
# Epoch 8/10
# 130/130 [==============================] - 1s 5ms/step - loss: 0.0896
# Epoch 9/10
# 130/130 [==============================] - 1s 5ms/step - loss: 0.0878
# Epoch 10/10
# 130/130 [==============================] - 1s 5ms/step - loss: 0.0870
# Epoch 1/10
# 130/130 [==============================] - 1s 5ms/step - loss: 0.0859
# Epoch 2/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.0841
# Epoch 3/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.0826
# Epoch 4/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0813
# Epoch 5/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.0804
# Epoch 6/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.0784
# Epoch 7/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.0770
# Epoch 8/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.0753
# Epoch 9/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.0746
# Epoch 10/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.0727
# Epoch 1/10
# ...
# Epoch 4/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1201
# Epoch 5/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1196
# Epoch 6/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1188
# Epoch 7/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.4328
# Epoch 8/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1513
# Epoch 9/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1505
# Epoch 10/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1502
# Epoch 1/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1493
# Epoch 2/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1483
# Epoch 3/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1482
# Epoch 4/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1470
# Epoch 5/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1462
# Epoch 6/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1459
# Epoch 7/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1453
# Epoch 8/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1444
# Epoch 9/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1432
# Epoch 10/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1424
# Epoch 1/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1415
# Epoch 2/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1409
# Epoch 3/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1397
# Epoch 4/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1389
# Epoch 5/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1391
# Epoch 6/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1371
# Epoch 7/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1360
# Epoch 8/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1354
# Epoch 9/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1342
# Epoch 10/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1331
# Epoch 1/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1325
# Epoch 2/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1308
# Epoch 3/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1299
# Epoch 4/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1282
# Epoch 5/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1266
# Epoch 6/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1262
# Epoch 7/10
# 130/130 [==============================] - 1s 4ms/step - loss: 2.4326
# Epoch 8/10
# 130/130 [==============================] - 0s 3ms/step - loss: 4.4755
# Epoch 9/10
# 130/130 [==============================] - 0s 4ms/step - loss: 1.2717
# Epoch 10/10
# 130/130 [==============================] - 1s 5ms/step - loss: 0.1216
# Epoch 1/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1187
# Epoch 2/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1171
# Epoch 3/10
# 130/130 [==============================] - 0s 3ms/step - loss: 8.1721
# Epoch 4/10
# 130/130 [==============================] - 0s 4ms/step - loss: 12.1389
# Epoch 5/10
# 130/130 [==============================] - 0s 4ms/step - loss: 8.9465
# Epoch 6/10
# 130/130 [==============================] - 0s 4ms/step - loss: 6.5791
# Epoch 7/10
# 130/130 [==============================] - 0s 3ms/step - loss: 4.3621
# Epoch 8/10
# 130/130 [==============================] - 0s 3ms/step - loss: 2.2538
# Epoch 9/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.4382
# Epoch 10/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1397
# Epoch 1/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1395
# Epoch 2/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1385
# Epoch 3/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1380
# Epoch 4/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1369
# Epoch 5/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1369
# Epoch 6/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1355
# Epoch 7/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1345
# Epoch 8/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1338
# Epoch 9/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1327
# Epoch 10/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1329
# Epoch 1/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1316
# Epoch 2/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1301
# Epoch 3/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1298
# Epoch 4/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1287
# Epoch 5/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1278
# Epoch 6/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1272
# Epoch 7/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1261
# Epoch 8/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1253
# Epoch 9/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1237
# Epoch 10/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1239
# Epoch 1/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1219
# Epoch 2/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1216
# Epoch 3/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1205
# Epoch 4/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1195
# Epoch 5/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1189
# Epoch 6/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1177
# Epoch 7/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1164
# Epoch 8/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1159
# Epoch 9/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1148
# Epoch 10/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1132
# Epoch 1/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1129
# Epoch 2/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1119
# Epoch 3/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1112
# Epoch 4/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1097
# Epoch 5/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1083
# Epoch 6/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1077
# Epoch 7/10
# 130/130 [==============================] - 0s 4ms/step - loss: 3.4202
# Epoch 8/10
# 130/130 [==============================] - 1s 4ms/step - loss: 2.8189
# Epoch 9/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.4088
# Epoch 10/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1378
# Epoch 1/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1369
# Epoch 2/10
# 130/130 [==============================] - 1s 5ms/step - loss: 0.1362
# Epoch 3/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1353
# Epoch 4/10
# 130/130 [==============================] - 1s 5ms/step - loss: 0.1348
# Epoch 5/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1341
# Epoch 6/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1337
# Epoch 7/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1333
# Epoch 8/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1324
# Epoch 9/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1318
# Epoch 10/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1311
# Epoch 1/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1297
# Epoch 2/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1300
# Epoch 3/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1287
# Epoch 4/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1280
# Epoch 5/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1269
# Epoch 6/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1267
# Epoch 7/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1256
# Epoch 8/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1252
# Epoch 9/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1235
# Epoch 10/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1228
# Epoch 1/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1222
# Epoch 2/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1204
# Epoch 3/10
# 130/130 [==============================] - 1s 5ms/step - loss: 0.1199
# Epoch 4/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1195
# Epoch 5/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1176
# Epoch 6/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1170
# Epoch 7/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1157
# Epoch 8/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1147
# Epoch 9/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1135
# Epoch 10/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1127
# Epoch 1/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1117
# Epoch 2/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1100
# Epoch 3/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1088
# Epoch 4/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1074
# Epoch 5/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1059
# Epoch 6/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1047
# Epoch 7/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1030
# Epoch 8/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1018
# Epoch 9/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1003
# Epoch 10/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0991
# Epoch 1/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.0971
# Epoch 2/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0959
# Epoch 3/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.0947
# Epoch 4/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.0930
# Epoch 5/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0920
# Epoch 6/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0891
# Epoch 7/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.0878
# Epoch 8/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.0859
# Epoch 9/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.0850
# Epoch 10/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.0829
# Epoch 1/10
# 130/130 [==============================] - 0s 4ms/step - loss: 9.0240
# Epoch 2/10
# 130/130 [==============================] - 1s 4ms/step - loss: 6.6059
# Epoch 3/10
# 130/130 [==============================] - 0s 4ms/step - loss: 3.7726
# Epoch 4/10
# 130/130 [==============================] - 0s 4ms/step - loss: 1.2466
# Epoch 5/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1134
# Epoch 6/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1084
# Epoch 7/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1075
# Epoch 8/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1063
# Epoch 9/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1056
# Epoch 10/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1044
# Epoch 1/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1035
# Epoch 2/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1025
# Epoch 3/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1010
# Epoch 4/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1000
# Epoch 5/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.0990
# Epoch 6/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0985
# Epoch 7/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.0968
# Epoch 8/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0959
# Epoch 9/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.0947
# Epoch 10/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0933
# Epoch 1/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.0928
# Epoch 2/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.0916
# Epoch 3/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0903
# Epoch 4/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.0888
# Epoch 5/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.0877
# Epoch 6/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0864
# Epoch 7/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0850
# Epoch 8/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0845
# Epoch 9/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.0830
# Epoch 10/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0821
# Epoch 1/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.0806
# Epoch 2/10
# 130/130 [==============================] - 1s 4ms/step - loss: 10.9425
# Epoch 3/10
# 130/130 [==============================] - 0s 4ms/step - loss: 14.2497
# Epoch 4/10
# 130/130 [==============================] - 1s 4ms/step - loss: 10.4049
# Epoch 5/10
# 130/130 [==============================] - 1s 4ms/step - loss: 7.6595
# Epoch 6/10
# 130/130 [==============================] - 1s 4ms/step - loss: 5.1567
# Epoch 7/10
# 130/130 [==============================] - 1s 4ms/step - loss: 2.8194
# Epoch 8/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6807
# Epoch 9/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.0915
# Epoch 10/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0909
# Epoch 1/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.0895
# Epoch 2/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.0883
# Epoch 3/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0873
# Epoch 4/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.0861
# Epoch 5/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0850
# Epoch 6/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.0845
# Epoch 7/10
# 130/130 [==============================] - 1s 4ms/step - loss: 4.5053
# Epoch 8/10
# 130/130 [==============================] - 1s 4ms/step - loss: 2.4390
# Epoch 9/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.2644
# Epoch 10/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1079
# Epoch 1/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1064
# Epoch 2/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1042
# Epoch 3/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1034
# Epoch 4/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1015
# Epoch 5/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1003
# Epoch 6/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.0985
# Epoch 7/10
# 130/130 [==============================] - 0s 4ms/step - loss: 0.0970
# Epoch 8/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.0952
# Epoch 9/10
# 130/130 [==============================] - 0s 3ms/step - loss: 0.0942
# Epoch 10/10
# 130/130 [==============================] - 1s 4ms/step - loss: 0.0925

# %% [markdown]
# ## TEST

# %% [markdown]
# !!!!! TEST AND SAMPLE_SUBMISSION DATA FILES SHOULD BE ADDED WHERE THIS DOCUMENT IS LOCATED BEFORE RUNNING THAT SECTION !!!!!

# %%
samp_sum = pd.read_csv('sample_submission.csv')
ten_digit_reference_df = pd.DataFrame(columns=samp_sum.columns)
ten_digit_reference_df['tripId'] =  samp_sum['tripId']
ten_digit_reference_df['UnixTimeMillis'] =  samp_sum['UnixTimeMillis']
ten_digit_reference_df['UnixTimeMillis'] = ten_digit_reference_df['UnixTimeMillis'].astype(str).str[:10].astype(int)

# %%
ten_digit_reference_df.shape
# Out:
# (71936, 4)

# %%
total_x_train = pd.DataFrame(index=range(71936), columns=['tripId', 'UnixTimeMillis', 'SvVelocityYEcefMetersPerSecond', 'SvVelocityZEcefMetersPerSecond',
                                                   'SvVelocityXEcefMetersPerSecond', 'RawPseudorangeMeters', 'SvClockBiasMeters', 'IsrbMeters', 'TroposphericDelayMeters',
                                                   'IonosphericDelayMeters', 'WlsPositionXEcefMeters', 'WlsPositionYEcefMeters', 'WlsPositionZEcefMeters','Accel_MeasurementX',
                                                     'Accel_MeasurementY', 'Accel_MeasurementZ','Mag_MeasurementX', 'Mag_MeasurementY','Mag_MeasurementZ',
                                                       'Gyro_MeasurementX', 'Gyro_MeasurementY', 'Gyro_MeasurementZ'])
total_x_train['tripId'] = ten_digit_reference_df['tripId'] 
total_x_train['UnixTimeMillis'] = ten_digit_reference_df['UnixTimeMillis']

# %%
# Initialize an empty DataFrame
data = {'tripId': [], 'UnixTimeMillis': [], 'LatitudeDegrees': [], 'LongitudeDegrees': []}
df = pd.DataFrame(data)
for main_doc_name in test_doc_list:
    sub_sub_list = list_subdirectories('test'+'/'+main_doc_name)
    for doc_name_list in sub_sub_list:

        #GNSS Data Part:

        #Reading the present gnss csv file
        df_gnss = pd.read_csv('test'+'/'+main_doc_name+'/'+doc_name_list+'/'+'device_gnss.csv', low_memory=False)

        data_gnss = pd.DataFrame()
        #Taking only the necessary columns
        data_gnss['utcTimeMillis'] = df_gnss["utcTimeMillis"]
        data_gnss['SvVelocityYEcefMetersPerSecond']= df_gnss["SvVelocityYEcefMetersPerSecond"]
        data_gnss['SvVelocityZEcefMetersPerSecond'] = df_gnss['SvVelocityZEcefMetersPerSecond']
        data_gnss['SvVelocityXEcefMetersPerSecond'] = df_gnss['SvVelocityXEcefMetersPerSecond']
        data_gnss['RawPseudorangeMeters'] = df_gnss['RawPseudorangeMeters']
        data_gnss['SvClockBiasMeters'] = df_gnss['SvClockBiasMeters']
        data_gnss['IsrbMeters'] = df_gnss['IsrbMeters']
        data_gnss['TroposphericDelayMeters'] = df_gnss['TroposphericDelayMeters']
        data_gnss['IonosphericDelayMeters'] = df_gnss['IonosphericDelayMeters']
        data_gnss['WlsPositionXEcefMeters'] = df_gnss['WlsPositionXEcefMeters']
        data_gnss['WlsPositionYEcefMeters'] = df_gnss['WlsPositionYEcefMeters']
        data_gnss['WlsPositionZEcefMeters'] = df_gnss['WlsPositionZEcefMeters']
                    

        #If more than one measurement is taken in the same second, average the measurements taken for the same time period and create one line of data for each second
        ten_digit_gnss = data_gnss.copy()
        ten_digit_gnss['utcTimeMillis'] = utc_to_unix_millis(ten_digit_gnss['utcTimeMillis'])
        ten_digit_gnss['utcTimeMillis'] = data_gnss['utcTimeMillis'].astype(str).str[:10].astype(int)
        gnss_data = ten_digit_gnss.groupby('utcTimeMillis').mean().reset_index()
        gnss_data = gnss_data.fillna(method='ffill')


        #IMU Data Part:
        #Reading the present imu csv file
        df_imu = pd.read_csv('test'+'/'+main_doc_name+'/'+doc_name_list+'/'+'device_imu.csv', low_memory=False)

        #Taking only the necessary columns
        data_imu = {'MessageType': df_imu["MessageType"],
                    'utcTimeMillis': df_imu["utcTimeMillis"],
                    'MeasurementX': df_imu["MeasurementX"],
                    'MeasurementY':df_imu["MeasurementY"],
                    'MeasurementZ':df_imu['MeasurementZ']
                    }
        # Transforming it to Pandas DataFrame to be able to make moves easily
        data_imu = pd.DataFrame(data_imu)
        
        #Since the accelerometer, gyro and magnetometer are combined in the same sensor in the IMU, it can be seen that the data received from these sensors 
        #are stored in a mixed manner. To fix this and evaluate each sensor data on its own, three sensor data are transferred to three different dataframes
        accel_imu_data = data_imu.loc[data_imu['MessageType'] == 'UncalAccel']
        mag_imu_data = data_imu.loc[data_imu['MessageType'] == 'UncalMag']
        gyro_imu_data = data_imu.loc[data_imu['MessageType'] == 'UncalGyro']
        
        #For the next step empty DataFrames are created
        ten_digit_accel = accel_imu_data.copy()
        ten_digit_accel['utcTimeMillis'] = utc_to_unix_millis(ten_digit_accel['utcTimeMillis'])

        ten_digit_mag = mag_imu_data.copy()
        ten_digit_mag['utcTimeMillis'] = utc_to_unix_millis(ten_digit_mag['utcTimeMillis'])

        ten_digit_gyro = gyro_imu_data.copy()
        ten_digit_gyro['utcTimeMillis'] = utc_to_unix_millis(ten_digit_gyro['utcTimeMillis'])

        #Data is currently processed and stored with millisecond precision, removing the last three digits to convert it to seconds precision
        ten_digit_accel['utcTimeMillis'] = accel_imu_data['utcTimeMillis'].astype(str).str[:10].astype(int)
        ten_digit_mag['utcTimeMillis'] = mag_imu_data['utcTimeMillis'].astype(str).str[:10].astype(int)
        ten_digit_gyro['utcTimeMillis'] = gyro_imu_data['utcTimeMillis'].astype(str).str[:10].astype(int)
        
        #If more than one measurement is taken in the same second, average the measurements taken for the same time period and create one line of data for each second
        imu_accel_df = ten_digit_accel.groupby('utcTimeMillis').mean().reset_index()
        imu_mag_df = ten_digit_mag.groupby('utcTimeMillis').mean().reset_index()
        imu_gyro_df = ten_digit_gyro.groupby('utcTimeMillis').mean().reset_index()

        imu_accel_df = imu_accel_df.fillna(method='ffill')
        imu_mag_df = imu_mag_df.fillna(method='ffill')
        imu_gyro_df = imu_gyro_df.fillna(method='ffill')


        #Since measurements for each sensor are recorded with the same column name, column names are customized for each sensor type to avoid confusion when combining data
        imu_accel_df = imu_accel_df.rename(columns={'MeasurementX': 'Accel_MeasurementX'})
        imu_accel_df = imu_accel_df.rename(columns={'MeasurementY': 'Accel_MeasurementY'})
        imu_accel_df = imu_accel_df.rename(columns={'MeasurementZ': 'Accel_MeasurementZ'})
        imu_mag_df = imu_mag_df.rename(columns={'MeasurementX': 'Mag_MeasurementX'})
        imu_mag_df = imu_mag_df.rename(columns={'MeasurementY': 'Mag_MeasurementY'})
        imu_mag_df = imu_mag_df.rename(columns={'MeasurementZ': 'Mag_MeasurementZ'})
        imu_gyro_df = imu_gyro_df.rename(columns={'MeasurementX': 'Gyro_MeasurementX'})
        imu_gyro_df = imu_gyro_df.rename(columns={'MeasurementY': 'Gyro_MeasurementY'})
        imu_gyro_df = imu_gyro_df.rename(columns={'MeasurementZ': 'Gyro_MeasurementZ'})

        

        #Recombining the processed imu data. Here, the same rows are determined by time, rows with the same time value are combined and the columns of 
        #accel, mag, and gyro measurements are stored separately. 
        total_imu_df = pd.merge(imu_accel_df, imu_mag_df, on='utcTimeMillis', how='inner')
        total_imu_df = pd.merge(total_imu_df, imu_gyro_df, on='utcTimeMillis', how='inner')

        total_imu_df = total_imu_df.fillna(method='ffill')
        
        #Finally, gnss and imu data are paired to take time into account and a single data is created. Thus, the 'X' part of the 
        #data set that will be used later when training the model is created
        x_part = pd.merge(gnss_data, total_imu_df, on='utcTimeMillis', how='inner')
        x_part = x_part.rename(columns={'utcTimeMillis': 'UnixTimeMillis'})
        x_part_wt = x_part.drop(columns=['UnixTimeMillis'])

        #Last check for NAN values
        x_part = x_part.fillna(method='ffill')
        x_part_wt = x_part_wt.fillna(method='ffill')

        # Predict with the CNN-GRU MODEL:
        predicted_cnn_gru = model_rnn.predict(x_part_wt)
        
        # Create a dictionary with empty lists for each column
        new_data = {
            'tripId': [],
            'UnixTimeMillis': [],
            'LatitudeDegrees': [],
            'LongitudeDegrees': []
        }

        # Create the new_data DataFrame
        new_data = pd.DataFrame()

        # Assign values to columns
        new_data['tripId'] = []
        new_data['UnixTimeMillis'] = x_part['UnixTimeMillis']
        new_data['tripId'] = main_doc_name + '/' + doc_name_list
        new_data['LatitudeDegrees'] = predicted_cnn_gru[:, 0]  # Assuming the first column contains LatitudeDegrees
        new_data['LongitudeDegrees'] = predicted_cnn_gru[:, 1]
        
        df_cnn_gru = df.append(pd.DataFrame(new_data), ignore_index=True)
# Out:
# 38/38 [==============================] - 0s 3ms/step
# C:\Users\ecems\AppData\Local\Temp\ipykernel_17976\506900934.py:133: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cnn_gru = df.append(pd.DataFrame(new_data), ignore_index=True)
# 53/53 [==============================] - 0s 3ms/step
# C:\Users\ecems\AppData\Local\Temp\ipykernel_17976\506900934.py:133: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cnn_gru = df.append(pd.DataFrame(new_data), ignore_index=True)
# 36/36 [==============================] - 0s 3ms/step
# C:\Users\ecems\AppData\Local\Temp\ipykernel_17976\506900934.py:133: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cnn_gru = df.append(pd.DataFrame(new_data), ignore_index=True)
# 40/40 [==============================] - 0s 3ms/step
# C:\Users\ecems\AppData\Local\Temp\ipykernel_17976\506900934.py:133: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cnn_gru = df.append(pd.DataFrame(new_data), ignore_index=True)
# 57/57 [==============================] - 0s 3ms/step
# C:\Users\ecems\AppData\Local\Temp\ipykernel_17976\506900934.py:133: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cnn_gru = df.append(pd.DataFrame(new_data), ignore_index=True)
# 78/78 [==============================] - 0s 4ms/step
# C:\Users\ecems\AppData\Local\Temp\ipykernel_17976\506900934.py:133: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cnn_gru = df.append(pd.DataFrame(new_data), ignore_index=True)
# 46/46 [==============================] - 0s 3ms/step
# C:\Users\ecems\AppData\Local\Temp\ipykernel_17976\506900934.py:133: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cnn_gru = df.append(pd.DataFrame(new_data), ignore_index=True)
# 44/44 [==============================] - 0s 3ms/step
# C:\Users\ecems\AppData\Local\Temp\ipykernel_17976\506900934.py:133: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cnn_gru = df.append(pd.DataFrame(new_data), ignore_index=True)
# 53/53 [==============================] - 0s 3ms/step
# C:\Users\ecems\AppData\Local\Temp\ipykernel_17976\506900934.py:133: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cnn_gru = df.append(pd.DataFrame(new_data), ignore_index=True)
# 76/76 [==============================] - 0s 3ms/step
# C:\Users\ecems\AppData\Local\Temp\ipykernel_17976\506900934.py:133: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cnn_gru = df.append(pd.DataFrame(new_data), ignore_index=True)
# 88/88 [==============================] - 0s 4ms/step
# C:\Users\ecems\AppData\Local\Temp\ipykernel_17976\506900934.py:133: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cnn_gru = df.append(pd.DataFrame(new_data), ignore_index=True)
# 142/142 [==============================] - 0s 3ms/step
# C:\Users\ecems\AppData\Local\Temp\ipykernel_17976\506900934.py:133: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cnn_gru = df.append(pd.DataFrame(new_data), ignore_index=True)
# 112/112 [==============================] - 0s 3ms/step
# C:\Users\ecems\AppData\Local\Temp\ipykernel_17976\506900934.py:133: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cnn_gru = df.append(pd.DataFrame(new_data), ignore_index=True)
# 53/53 [==============================] - 0s 3ms/step
# C:\Users\ecems\AppData\Local\Temp\ipykernel_17976\506900934.py:133: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cnn_gru = df.append(pd.DataFrame(new_data), ignore_index=True)
# 37/37 [==============================] - 0s 3ms/step
# C:\Users\ecems\AppData\Local\Temp\ipykernel_17976\506900934.py:133: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cnn_gru = df.append(pd.DataFrame(new_data), ignore_index=True)
# 66/66 [==============================] - 0s 3ms/step
# C:\Users\ecems\AppData\Local\Temp\ipykernel_17976\506900934.py:133: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cnn_gru = df.append(pd.DataFrame(new_data), ignore_index=True)
# 68/68 [==============================] - 0s 3ms/step
# C:\Users\ecems\AppData\Local\Temp\ipykernel_17976\506900934.py:133: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cnn_gru = df.append(pd.DataFrame(new_data), ignore_index=True)
# 44/44 [==============================] - 0s 3ms/step
# C:\Users\ecems\AppData\Local\Temp\ipykernel_17976\506900934.py:133: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cnn_gru = df.append(pd.DataFrame(new_data), ignore_index=True)
# 61/61 [==============================] - 0s 4ms/step
# C:\Users\ecems\AppData\Local\Temp\ipykernel_17976\506900934.py:133: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cnn_gru = df.append(pd.DataFrame(new_data), ignore_index=True)
# 50/50 [==============================] - 0s 3ms/step
# C:\Users\ecems\AppData\Local\Temp\ipykernel_17976\506900934.py:133: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cnn_gru = df.append(pd.DataFrame(new_data), ignore_index=True)
# 42/42 [==============================] - 0s 3ms/step
# C:\Users\ecems\AppData\Local\Temp\ipykernel_17976\506900934.py:133: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cnn_gru = df.append(pd.DataFrame(new_data), ignore_index=True)
# 44/44 [==============================] - 0s 4ms/step
# C:\Users\ecems\AppData\Local\Temp\ipykernel_17976\506900934.py:133: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cnn_gru = df.append(pd.DataFrame(new_data), ignore_index=True)
# 42/42 [==============================] - 0s 3ms/step
# C:\Users\ecems\AppData\Local\Temp\ipykernel_17976\506900934.py:133: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cnn_gru = df.append(pd.DataFrame(new_data), ignore_index=True)
# 45/45 [==============================] - 0s 3ms/step
# C:\Users\ecems\AppData\Local\Temp\ipykernel_17976\506900934.py:133: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cnn_gru = df.append(pd.DataFrame(new_data), ignore_index=True)
# 59/59 [==============================] - 0s 3ms/step
# C:\Users\ecems\AppData\Local\Temp\ipykernel_17976\506900934.py:133: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cnn_gru = df.append(pd.DataFrame(new_data), ignore_index=True)
# 58/58 [==============================] - 0s 4ms/step
# C:\Users\ecems\AppData\Local\Temp\ipykernel_17976\506900934.py:133: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cnn_gru = df.append(pd.DataFrame(new_data), ignore_index=True)
# 56/56 [==============================] - 0s 3ms/step
# C:\Users\ecems\AppData\Local\Temp\ipykernel_17976\506900934.py:133: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cnn_gru = df.append(pd.DataFrame(new_data), ignore_index=True)
# 37/37 [==============================] - 0s 3ms/step
# C:\Users\ecems\AppData\Local\Temp\ipykernel_17976\506900934.py:133: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cnn_gru = df.append(pd.DataFrame(new_data), ignore_index=True)
# 43/43 [==============================] - 0s 3ms/step
# C:\Users\ecems\AppData\Local\Temp\ipykernel_17976\506900934.py:133: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cnn_gru = df.append(pd.DataFrame(new_data), ignore_index=True)
# 44/44 [==============================] - 0s 3ms/step
# C:\Users\ecems\AppData\Local\Temp\ipykernel_17976\506900934.py:133: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cnn_gru = df.append(pd.DataFrame(new_data), ignore_index=True)
# 66/66 [==============================] - 0s 3ms/step
# C:\Users\ecems\AppData\Local\Temp\ipykernel_17976\506900934.py:133: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cnn_gru = df.append(pd.DataFrame(new_data), ignore_index=True)
# 67/67 [==============================] - 0s 3ms/step
# C:\Users\ecems\AppData\Local\Temp\ipykernel_17976\506900934.py:133: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cnn_gru = df.append(pd.DataFrame(new_data), ignore_index=True)
# 41/41 [==============================] - 0s 3ms/step
# C:\Users\ecems\AppData\Local\Temp\ipykernel_17976\506900934.py:133: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cnn_gru = df.append(pd.DataFrame(new_data), ignore_index=True)
# 62/62 [==============================] - 0s 3ms/step
# C:\Users\ecems\AppData\Local\Temp\ipykernel_17976\506900934.py:133: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cnn_gru = df.append(pd.DataFrame(new_data), ignore_index=True)
# 32/32 [==============================] - 0s 3ms/step
# C:\Users\ecems\AppData\Local\Temp\ipykernel_17976\506900934.py:133: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cnn_gru = df.append(pd.DataFrame(new_data), ignore_index=True)
# 41/41 [==============================] - 0s 3ms/step
# C:\Users\ecems\AppData\Local\Temp\ipykernel_17976\506900934.py:133: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cnn_gru = df.append(pd.DataFrame(new_data), ignore_index=True)
# 42/42 [==============================] - 0s 3ms/step
# C:\Users\ecems\AppData\Local\Temp\ipykernel_17976\506900934.py:133: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cnn_gru = df.append(pd.DataFrame(new_data), ignore_index=True)
# 47/47 [==============================] - 0s 3ms/step
# C:\Users\ecems\AppData\Local\Temp\ipykernel_17976\506900934.py:133: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cnn_gru = df.append(pd.DataFrame(new_data), ignore_index=True)
# 51/51 [==============================] - 0s 3ms/step
# C:\Users\ecems\AppData\Local\Temp\ipykernel_17976\506900934.py:133: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cnn_gru = df.append(pd.DataFrame(new_data), ignore_index=True)
# 47/47 [==============================] - 0s 3ms/step
# C:\Users\ecems\AppData\Local\Temp\ipykernel_17976\506900934.py:133: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cnn_gru = df.append(pd.DataFrame(new_data), ignore_index=True)

# %%
for index, row in ten_digit_reference_df.iterrows():
    trip_id = row['tripId']
    unix_time_millis = row['UnixTimeMillis']
    
    matched_row = df_cnn_gru[(df_cnn_gru['tripId'] == trip_id) & (df_cnn_gru['UnixTimeMillis'] == unix_time_millis)]
    
    # Eğer eşleşen bir satır bulunduysa
    if not matched_row.empty:
        # LatitudeDegrees ve LongitudeDegrees sütunlarını ilgili hücrelere atayın
        ten_digit_reference_df.at[index, 'LatitudeDegrees'] = matched_row['LatitudeDegrees'].iloc[0]
        ten_digit_reference_df.at[index, 'LongitudeDegrees'] = matched_row['LongitudeDegrees'].iloc[0]
    else:
        # Eşleşen bir satır bulunamazsa, ilgili hücrelere NaN (veya başka bir varsayılan değer) atayın
        ten_digit_reference_df.at[index, 'LatitudeDegrees'] = None
        ten_digit_reference_df.at[index, 'LongitudeDegrees'] = None

# %%
# Eksik değerleri bir üstündeki değerlerle dolduralım
df_filled = ten_digit_reference_df.fillna(method='ffill')

print(df_filled)
# Out:
#                                          tripId  UnixTimeMillis  \
# 0         2020-12-11-19-30-us-ca-mtv-e/pixel4xl      1607715055
# 1         2020-12-11-19-30-us-ca-mtv-e/pixel4xl      1607715056
# 2         2020-12-11-19-30-us-ca-mtv-e/pixel4xl      1607715057
# 3         2020-12-11-19-30-us-ca-mtv-e/pixel4xl      1607715058
# 4         2020-12-11-19-30-us-ca-mtv-e/pixel4xl      1607715059
# ...                                         ...             ...
# 71931  2023-06-15-18-49-us-ca-sjc-ce1/pixel7pro      1686856468
# 71932  2023-06-15-18-49-us-ca-sjc-ce1/pixel7pro      1686856469
# 71933  2023-06-15-18-49-us-ca-sjc-ce1/pixel7pro      1686856470
# 71934  2023-06-15-18-49-us-ca-sjc-ce1/pixel7pro      1686856471
# 71935  2023-06-15-18-49-us-ca-sjc-ce1/pixel7pro      1686856472
#
#       LatitudeDegrees LongitudeDegrees
# 0                None             None
# 1                None             None
# 2                None             None
# 3                None             None
# 4                None             None
# ...               ...              ...
# 71931            None             None
# 71932            None             None
# 71933            None             None
# 71934            None             None
# 71935            None             None
#
# [71936 rows x 4 columns]

# %%
df_filled['UnixTimeMillis'] = samp_sum['UnixTimeMillis'] 
# Export the final DataFrame to a CSV file
df_filled.to_csv('deneme.csv', index=False)
